# %% [markdown]
# ### Plot all of the solar system orbits by adding code cells below using matplotlib

# %%
# Import modules that contain functions we need
import pandas as pd # pandas is common for data science
import numpy as np #N umPy is used a lot in science
import math # we need the math class for pi
# %matplotlib inline 
import matplotlib.pyplot as plt # MatPlotLib is the plotting standard

# %%
# Read in the Github data that will be used for the calculations.
data1 = pd.read_csv("solar_system_orbits.csv")
data1
# Out:
#       Planet  Semimajor Axis (AU)  Period (y)  Eccentricity  Mass of Planet
# 0    Mercury                 0.39        0.24          0.21             NaN
# 1      Venus                 0.72        0.60          0.01             NaN
# 2      Earth                 1.00        1.00          0.02             NaN
# 3       Mars                 1.52        1.88          0.09             NaN
# 4      Ceres                 2.77        4.60          0.08             NaN
# 5     Pallas                  NaN         NaN           NaN             NaN
# 6    Jupiter                 5.20       11.86          0.05             NaN
# 7     Saturn                 9.54       29.46          0.06             NaN
# 8     Uranus                19.19       84.01          0.05             NaN
# 9    Neptune                30.06      164.82          0.01             NaN
# 10     Pluto                  NaN         NaN           NaN             NaN
# 11     Vesta                  NaN         NaN           NaN             NaN
# 12     Encke                  NaN         NaN           NaN             NaN
# 13    Halley                  NaN         NaN           NaN             NaN
# 14    Haumea                  NaN         NaN           NaN             NaN
# 15  Makemake                  NaN         NaN           NaN             NaN
# 16      Eris                  NaN         NaN           NaN             NaN

# %%
def xval(t):
    return a*np.cos(t)

def yval(t):
    return b*np.sin(t)

## the linspace method defines the actual number points within the range
x = np.linspace(0,2*np.pi, num=1000)
y = np.linspace(0,2*np.pi, num=1000)

# %%
planets = ["Mercury", "Earth", "Jupiter", "Haumea"]

# Mercury
a = np.array(data1['Semimajor Axis (AU)'][0])
T = np.array(data1['Period (y)'][0])
e = np.array(data1['Eccentricity'][0])
c=a*e
b=(a**2-c**2)**0.5
plt.title(planets[0]+" Orbit!")
plt.xlabel("a AU")
plt.ylabel("b AU");
plt.gca().set_aspect('equal')
plt.plot(xval(y),yval(x))

# Mercury
a = np.array(data1['Semimajor Axis (AU)'][0])
T = np.array(data1['Period (y)'][0])
e = np.array(data1['Eccentricity'][0])
c=a*e
b=(a**2-c**2)**0.5
plt.title(planets[1]+" Orbit!")
plt.xlabel("a AU")
plt.ylabel("b AU");
plt.gca().set_aspect('equal')
plt.plot(xval(y),yval(x))
plt.show()
