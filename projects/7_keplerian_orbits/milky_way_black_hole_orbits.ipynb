# %% [markdown]
# ## Plotting the orbits of the closest stars (S Cluster) orbiting the Central Black Hole (Sagittarius A*) of the Miky Way!

# %%
from IPython.display import YouTubeVideo
# S Cluster Stars orbits Milky Way central black hole!
YouTubeVideo('B0QRpid5_QU')

# %%
from IPython.display import YouTubeVideo
# Animation of S Cluster Stars orbiting Milky Way central black hole!
YouTubeVideo('sls28MTNFm0')

# %% [markdown]
# ### Compute and plot S-Cluster Orbits around the Central Supermassive Black Hole of the Milky Way!
#
# 1. Complete all of the missing s-cluster orbital parameters by adding code cells below.
# 1. Upload a new 'updated_solar_system_orbits.csv' to the project.
# 1. Plot the orbits of the S-Cluster using matplotlib

# %% [markdown]
# ![Some Hints](IMG_5148.JPG)

# %%
# Import modules that contain functions we need
import pandas as pd # pandas is common for data science
import numpy as np # NumPy is used a lot in science
import math # we need the math class for pi
# %matplotlib inline 
import matplotlib.pyplot as plt # MatPlotLib is the plotting standard

# %%
# Read in the Github data that will be used for the calculations.
data1 = pd.read_csv("s_cluster_orbital_elements.csv")
data1
# Out:
#      Star  Semi-major axis, miili-parsecs  Uncertainty in a  ellipticity  \
# 0   S1                             22.675             0.257        0.665
# 1   S2                              5.034             0.001        0.887
# 2   S8                             16.637             0.182        0.768
# 3   S9                             11.125             0.030        0.791
# 4   S12                            11.962             0.105        0.906
# 5   S13                             9.580             1.264        0.415
# 6   S17                            13.037             0.794        0.421
# 7   S19                            11.122             3.130        0.626
# 8   S24                            45.115             7.475        0.682
# 9   S29                            34.694             3.803        0.335
# 10  S31                            16.582             4.514        0.521
# 11  S39                            13.919             2.068        0.831
# ...
