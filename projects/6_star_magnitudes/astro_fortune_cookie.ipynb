# %% [markdown]
# # Astronomical Fortune Cookie Lab!

# %% [markdown]
# ### Instructions for generating Color Image and Annotating with Science Data

# %% [markdown]
# ### 1. [Access Las Cumbres Observatory Observing Portal](https://observe.lco.global/?limit=20)

# %% [markdown]
# ![query.png](attachment:140499da-3974-4273-aecb-bd0415d32883.png)

# %% [markdown]
# ![ra_dec.png](attachment:b69bdbf8-ee04-4490-a6d0-32969a16cca2.png)

# %%
target = 'Hyades'
target_ra = '04:29:47.28'
target_dec = '16:56:52.8'
simbad_query_string = f'{target_ra}+{target_dec}'
print(simbad_query_string)
# Out:
# 04:29:47.28+16:56:52.8

# %% [markdown]
# ### 2. [Query SIMBAD catalog for your Sky Chart](http://simbad.cds.unistra.fr/simbad/sim-fcoo)
# #### * Then Click the Submit Query Button!

# %% [markdown]
# ![simbad.png](attachment:c74354a1-907a-4e0f-b46e-87b76358ea81.png)

# %% [markdown]
# ![simbad_zoom.png](attachment:1db2edcd-c51f-410d-b957-734e4f7fb205.png)

# %% [markdown]
# ![simbad_target_image.png](attachment:9f3010f2-557a-4419-a2ae-fcf5fd2919e4.png)

# %% [markdown]
# ### 3. Go to your original Query from LCO

# %% [markdown]
# ![data_link.png](attachment:3342da8a-9a63-418d-959c-d439eb1b01be.png)

# %% [markdown]
# ![get_image.png](attachment:a63968fa-7f45-48fa-8871-d8ea1a6e8da1.png)

# %% [markdown]
# ### * Go fortune Hunting in this image for other targets such as galaxies, nebulae, interesting stars etc.
# ### * See if you can find these targets in your original image from the telescope
# ### * Annotate these targets digitally and embed the image below!
